# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
warnings.filterwarnings('ignore')

# %%
stats = pd.read_csv('DemographicData.csv')
stats.columns = ('CountryName','CountryCode','BirthRate',\
                'InternetUsers','IncomeGroup')
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
vis1 = sns.lmplot(data=stats, x='InternetUsers',y='BirthRate',fit_reg=False) #lm is Linear Model,

# %%
vis1 = sns.lmplot(data=stats, x='InternetUsers',y='BirthRate',\
                  fit_reg=False, hue='IncomeGroup',size=10) #hue is for color

# %% [markdown]
# ---

# %%
#We can see countries which have more internet users, they do not make children

# %%
#-------KEYWORD ARGUMENTIS IN PYTHON (ADVANCED TUTORIAL)

# %%
#marker size:
vis1 = sns.lmplot(data=stats, x='InternetUsers',y='BirthRate',\
                  fit_reg=False, hue='IncomeGroup',size=8,\
                 scatter_kws={'s':100})
